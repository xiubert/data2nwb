# %% [markdown]
# # Converting 2P data with ophys and pupillometry to NWB format
#
# - Requires subject metadata in `./data/animalList.csv` and experiment metadata in `./data/experimentMetadata.csv`
# - Experimenter and imaging parameters are set in a YAML config file (see `configs/`).
#     - Copy `configs/params_general.yaml`, fill in your settings, and update `config_path` below.
# - For batch conversion over multiple experiments, use the command line script (see README).
# - For pupillometry tables in .mat files, require matlab component to reformat table as struct to be able to load into python. See: `./extra/tableMAT2StructMAT.m`.
# - Explore NWB output file with `neurosift`
#     1. in python env: `pip install --upgrade neurosift`
#     2. `neurosift view-nwb AA0304_DANDI.nwb`
# - After conversion, confirm NWB format conforms to DANDI standards w/ nwbinspector:
#     1. in python env: `pip install -U nwbinspector`
#     2. `nwbinspector "AA0304.nwb" --config dandi`

# %% [markdown]
# ## Run NWB data standardization function on a single experiment:

# %%
import pandas as pd
import ast

subjects = pd.read_csv('./data/animalList.csv')
subjects = subjects.set_index('subject_id')
experiments = pd.read_csv('./data/experimentMetadata.csv')
experiments = experiments.set_index('subject_id')
experiments['keywords'] = experiments['keywords'].apply(ast.literal_eval)

subject_id = 'AA0314'
[print(f"{c}: {subjects.loc[subject_id][c]}") for c in subjects.columns]
[print(f"{c}: {experiments.loc[subject_id][c]}") for c in experiments.columns]

# %%
import os
import yaml
import lib.nwbScanImage

# set data path and config
dataPath = "/media/DATA/backups/sutter2P_backup/D_drive/Cody_et_al_2024"
config_path = "./configs/params_PC.yaml"

with open(config_path) as f:
    cfg = yaml.safe_load(f)

outputNWBpath = os.path.join(dataPath, subject_id, f"{subject_id}_fix.nwb")

subject = lib.nwbScanImage.setSubject(
    subject_id=subject_id,
    age="P47D",
    species="Mus musculus",
    sex="F",
    genotype="C57BL6/J",
    description="Injected on 4/7/2021 with AAV9.CaMKII.GCaMP6f.WPRE.SV40 at 1:6 into right ACtx"
)

lib.nwbScanImage.genNWBfromScanImage_pc(
    experimentID=subject_id,
    dataPath=dataPath,
    NWBoutputPath=outputNWBpath,
    subject=subject,
    session_description=experiments.loc[subject_id]['session_description'],
    experiment_description=experiments.loc[subject_id]['experiment_description'],
    keywords=experiments.loc[subject_id]['keywords'],
    **cfg['nwb_file'],
    **cfg['imaging']
)

# %% [markdown]
# ## Batch conversion over multiple experiments:
# Run from the command line. `dataPath` is the top-level directory containing one folder per subject (named by `subject_id`). CSV and config paths default to `./data/` and `./configs/params_PC.yaml` but can be overridden:
# ```bash
# # all defaults
# python scanimage2nwb.py /path/to/data
#
# # custom paths
# python scanimage2nwb.py /path/to/data \
#     --subjects /path/to/animalList.csv \
#     --experiments /path/to/experimentMetadata.csv \
#     --config ./configs/my_params.yaml
# ```
